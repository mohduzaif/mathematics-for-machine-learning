# %%
import numpy as np

# %%
# 0D tensor or Scaler.

# %%
zeroD_tensor = np.array(3)
zeroD_tensor
# Out:
# array(3)

# %%
# 1D tensor or vector.

# %%
oneD_tensor = np.array([1, 2, 3, 4, 5])

oneD_tensor
# Out:
# array([1, 2, 3, 4, 5])

# %%
oneD_tensor.ndim
# Out:
# 1

# %%
# 1. It is a vector of dimension 5.
# 2. But it is tensor of 1 dimension.

# %%
# 2D tensor or matrix.

# %%
twoD_tensor = np.array([[1, 2, 3], [4, 5, 6]])
twoD_tensor
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
twoD_tensor.ndim
# Out:
# 2

# %%
# 3D_tensor

# %%
threeD_tensor = np.array([[[1], [3]], [[4], [6]]] )
threeD_tensor
# Out:
# array([[[1],
#         [3]],
#
#        [[4],
#         [6]]])

# %%
threeD_tensor.ndim
# Out:
# 3
