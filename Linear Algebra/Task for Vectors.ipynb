# %%
import numpy as np

# %%
# Given the vectors A = [1, 2, 3] and B = [4, 5, 6], calculate the element-wise product of the two vectors.

A = np.array([1, 2, 3])
B = np.array([4, 5, 6])

product = A * B
print('Element wise product is ', product)
# Out:
# Element wise product is  [ 4 10 18]

# %%
# Find the magnitude of the vector C = [2, -3, 1].

C = [2, -3, 1]
print('Magnitude of C is', np.linalg.norm(C))
# Out:
# Magnitude of C is 3.7416573867739413

# %%
# Given the vectors D = [1, 2, 3] and E = [4, 5, 6], calculate the cosine of the angle between them.

D = np.array([1, 2, 3])
E = np.array([4, 5, 6])

mag_D = np.linalg.norm(D)
mag_E = np.linalg.norm(E)

product = np.dot(D, E)

cosine_angle = product / (mag_D * mag_E)

print(cosine_angle)
# Out:
# 0.9746318461970762

# %%
# Given the vectors F = [1, 2, 3] and G = [4, 5, 6], calculate the cross product of the two vectors. 

F = np.array([1, 2, 3] )
G = np.array([4, 5, 6])

np.cross(F, G)
# Out:
# array([-3,  6, -3])

# %%
# Given the vector H = [2, 4, 6], shift the vector +1 unit in each dimension. 
H = np.array([2, 4, 6]) 

print(H + 1)
print(H - 1)
# Out:
# [3 5 7]
# [1 3 5]

# %%
#  Given the vectors I = [1, 2, 3] and J = [4, 5, 6], calculate the projection of vector I onto vector J.

import numpy as np

I = np.array([1, 2, 3])
J = np.array([4, 5, 6])

projection_I_onto_J = (np.dot(I, J) / np.dot(J, J)) * J

print(projection_I_onto_J)
# Out:
# [1.66233766 2.07792208 2.49350649]

# %% [markdown]
# ### Q7. Consider the 2D - position vector a = (1, 3). If b is the point (5, 4), find the vector `ab` and the vector sum `a + ab`. Provide a sketch plot.
#
# Note: Search for quiver, to plot an arrow.

# %%
# Solution
import numpy as np
import matplotlib.pyplot as plt

a = np.array([1, 3])
b = np.array([5, 4])

# Calculate vector ab
ab = b - a
print("Vector ab:", ab)

# Calculate vector sum a + ab
a_plus_ab = a + ab
print("Vector sum a + ab:", a_plus_ab)

# Plot the vectors a, b, and ab
origin = np.array([0, 0])

plt.quiver(*origin, a[0], a[1], angles='xy', scale_units='xy', scale=1, color='r', label='a')
plt.scatter(b[0], b[1], color='b', label='b')
plt.quiver(*a, ab[0], ab[1], angles='xy', scale_units='xy', scale=1, color='g', label='ab')
plt.quiver(*origin, a_plus_ab[0], a_plus_ab[1], angles='xy', scale_units='xy', scale=1, color='m', label='a+ab')

plt.xlim(-1, 7)
plt.ylim(-1, 7)
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid()
plt.show()
# Out:
# Vector ab: [4 1]
# Vector sum a + ab: [5 4]

# %%
# Given two 2D vectors u and v where u = [-1, 4] and v = [3, -2], 
# find the dot product u . v, the angle between u and v, and the projection of u onto v.A

# Solution
import numpy as np

u = np.array([-1, 4])
v = np.array([3, -2])

# Dot product of u and v
dot_uv = np.dot(u, v)
print("Dot product of u and v:", dot_uv)

# Angle between u and v in radians
cos_theta = dot_uv / (np.linalg.norm(u) * np.linalg.norm(v))
theta = np.arccos(cos_theta)
print("Angle between u and v in radians:", theta)

# Projection of u onto v
proj_u_onto_v = (np.dot(u, v) / np.dot(v, v)) * v
print("Projection of u onto v:", proj_u_onto_v)
# Out:
# Dot product of u and v: -11
# Angle between u and v in radians: 2.4037775934693286
# Projection of u onto v: [-2.53846154  1.69230769]

# %%
# Given a hyperplane defined by the equation 3x - 2y + z = 1, find two different points that lie on this hyperplane.


# Solution
import numpy as np

# Hyperplane equation: 3x - 2y + z = 1

# Let x = 0, y = 0
z = 1
p1 = np.array([0, 0, z])
print("Point 1:", p1)

# Let x = 2, y = 5
x = 2
y = 5
z = 3*x - 2*y + 1
p2 = np.array([x, y, z])
print(p2)
# Out:
# Point 1: [0 0 1]
# [ 2  5 -3]

# %% [markdown]
# Find a nearest point from a given array of points to a point P1.
# P1 - (3,9,3)
#
# Array of points :
#
# [[1, 8, 5],
# [8, 8, 2],
# [7, 9, 1],
# [5, 6, 3],
# [9, 1, 2],
# [6, 5, 9],
# [5, 8, 6],
# [3, 4, 8],
# [6, 8, 4],
# [7, 2, 7]]

# %%
# Solution

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Generate array of 10 random 3-D points
points = np.array([[1, 8, 5],
       [8, 8, 2],
       [7, 9, 1],
       [5, 6, 3],
       [9, 1, 2],
       [6, 5, 9],
       [5, 8, 6],
       [3, 4, 8],
       [6, 8, 4],
       [7, 2, 7]])

# Define target point
target = np.array([3, 9, 3])

# Calculate distances between target point and each point in the array
distances = np.linalg.norm(points - target, axis=1)

# Find index of point with shortest distance
index_min_distance = np.argmin(distances)

# Retrieve point with shortest distance
point_min_distance = points[index_min_distance]

print("Nearest point:", point_min_distance)


# Uncomment below to see plot
# Create figure and axis for 3-D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot all points as blue
ax.scatter(points[:, 0], points[:, 1], points[:, 2], color='blue')

# Plot target point as red
ax.scatter(target[0], target[1], target[2], color='red')

# Plot nearest point as green
ax.scatter(point_min_distance[0], point_min_distance[1], point_min_distance[2], color='yellow')

# Set labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3-D Scatter Plot')

# Show plot
plt.show()
# Out:
# Nearest point: [1 8 5]
